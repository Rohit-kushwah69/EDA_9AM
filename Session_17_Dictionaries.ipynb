# %%
names=['Ramesh','Suresh','Mahesh']
age=[20,22,24]
# 'Ramesh age is 20'
# 'Suresh age is 22'
# 'Mahesh age is 24'

# %%
names[0] age is age[0]    
names[1] age is age[1]
names[2] age is age[2]

names[i] age is age[i]

# %%
for i in range(len(names)):
    print(f'{names[i]} age is {age[i]}')
# Out:
# Ramesh age is 20
# Suresh age is 22
# Mahesh age is 24

# %%
l1=[10,20,30]
l2=[1,2,3]
# l=[11,22,33]
l=[]
for i in range(len(l1)):
    l.append(l1[i]+l2[i])
l
# Out:
# [11, 22, 33]

# %% [markdown]
# **zip**

# %%
names,age
# Out:
# (['Ramesh', 'Suresh', 'Mahesh'], [20, 22, 24])

# %%
zip(names,age)

# %%
list(zip(names,age))
# Out:
# [('Ramesh', 20), ('Suresh', 22), ('Mahesh', 24)]

# %%
for i in zip(names,age):
    print(i)
# Out:
# ('Ramesh', 20)
# ('Suresh', 22)
# ('Mahesh', 24)

# %%
n1=10,20
n1
# Out:
# (10, 20)

# %%
n1,n2=10,20
n2
# Out:
# 20

# %%
for i,j in zip(names,age):
    print(i,j)
# Out:
# Ramesh 20
# Suresh 22
# Mahesh 24

# %%
for i,j in zip(names,age):
    print(f'{i} age is {j}')
# Out:
# Ramesh age is 20
# Suresh age is 22
# Mahesh age is 24

# %%
l=[]
for i,j in zip(l1,l2):
    l.append(i+j)
l
# Out:
# [11, 22, 33]

# %% [markdown]
# - zip is mainly used for both lists have same length
#
# - if you want use for different lenghth you can use it

# %%
l1=[10,20,30]
l2=['A','B']
list(zip(l1,l2))
# Out:
# [(10, 'A'), (20, 'B')]

# %%
l1=[10,20,30,40]
l2=[1,2,3]
#l=[11,22,33,40]
l=[]
for i in range(len(l1)):  # 0,1,2,3
    if i<len(l2):
        l.append(l1[i]+l2[i])
    else:
        l.append(l1[i])
# step-1: i=0  if 0<3  True  0 10+1=11
# step-2: i=1  if 1<3  True  1 20+2=22
# step-3: i=2  if 2<3  True  2 30+3 =33
# step-4: i=3  if 3<3  F  else 3 40

l
# Out:
# [11, 22, 33, 40]

# %%
l=[10,20,30,40]
for i in range(5):
    if i<len(l):  
        print(i,l[i])
# 0<4  T  
# 1<4
# 2<4
# 3<4
# 4<4  F
# Out:
# 0 10
# 1 20
# 2 30
# 3 40

# %%
from itertools import zip_longest

# %%
l1=[10,20,30,40]
l2=[1,2,3]
list(zip(l1,l2))
# Out:
# [(10, 1), (20, 2), (30, 3)]

# %%
l1=[10,20,30,40]
l2=[1,2,3]
list(zip_longest(l1,l2))
# Out:
# [(10, 1), (20, 2), (30, 3), (40, None)]

# %%
l1=[10,20,30,40]
l2=[1,2,3]
new=list(zip_longest(l1,l2,fillvalue=0))
out=[i+j for i,j in new]
out
# Out:
# [11, 22, 33, 40]

# %% [markdown]
# - zip means combine the two elements which are have some relation
#
# - this gave an idea about dictionary
#
# - Ramesh is related with 20
#
# - Suresh is related with 22
#
# - these related values we can form a dictionary
#
# - dictionary is a key-value pair
#
# - represnt with {}
#
# - {key:value}
#
# - assume ramesh is key and 20 is value : {'Ramesh':20}

# %%
d1={'Ramesh':20,'Suresh':22,'Mahesh':24}
d1
# Out:
# {'Ramesh': 20, 'Suresh': 22, 'Mahesh': 24}

# %%
d2={20:'Ramesh',22:'Suresh',24:'Mahesh'}
d2
# Out:
# {20: 'Ramesh', 22: 'Suresh', 24: 'Mahesh'}

# %%
dict1={'Ramesh':20,'Suresh':22,'Mahesh':24} # w
dict2={20:'Ramesh',22:'Suresh',24:'Mahesh'} # w
dict3={'20':'Ramesh','22':'Suresh','24':'Mahesh'} # w
dict4={20:20,22:22,24:24}
dict5={'Ramesh':20,'Ramesh':22} 
dict6={'Ramesh':20,'Ramesh':20}
dict7={'Ramesh':20,'Suresh':20} 
dict8={'Ramesh':20,
       20:'Suresh',
       'Sathish':True,
       False:True}
dict9={'Names':['Ramesh','Suresh','Mahesh']}
dict10={['Ramesh','Suresh','Mahesh']:'Names'}  
dict11={'Names':('Ramesh','Suresh','Mahesh')}
dict12={('Ramesh','Suresh','Mahesh'):'Names'} 
dict13={}
dict14={{'Ramesh':20}:21}
dict14

# %%
dict3={'20':'Ramesh','22':'Suresh','24':'Mahesh'}
dict4={20:20,22:22,24:24}
dict4
# Out:
# {20: 20, 22: 22, 24: 24}

# %%
dict5={'Ramesh':20,'Ramesh':22}
dict5 
#same key different values then choose:latest value
# Out:
# {'Ramesh': 22}

# %%
dict6={'Ramesh':20,'Ramesh':20}
dict6 # Duplicates are not allowed
# Out:
# {'Ramesh': 20}

# %%
dict7={'Ramesh':20,'Suresh':20}
dict7 
# keys can not be duplicate
# values can be dupicated
# Out:
# {'Ramesh': 20, 'Suresh': 20}

# %% [markdown]
# **KEYS ARE VERY IMPORTANT**

# %%
dict8={'Ramesh':20,
       20:'Suresh',
       'Sathish':True,
       False:True}
dict8 
# Dictionary is a heterogeneous
# Out:
# {'Ramesh': 20, 20: 'Suresh', 'Sathish': True, False: True}

# %%
dict9={'Names':['Ramesh','Suresh','Mahesh']}
dict9={'Ramesh':[20,'pune','UG']}
dict9={'Fruites':['A','B','C']}
# Out:
# {'Names': ['Ramesh', 'Suresh', 'Mahesh']}

# %%
dict10={['Ramesh','Suresh','Mahesh']:'Names'}
dict10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 dict10={['Ramesh','Suresh','Mahesh']:'Names'}
#       2 dict10
#
# TypeError: unhashable type: 'list'

# %%
dict11={'Names':('Ramesh','Suresh','Mahesh')}
dict11
# Out:
# {'Names': ('Ramesh', 'Suresh', 'Mahesh')}

# %%
dict12={('Ramesh','Suresh','Mahesh'):'Names'} 
dict12
# Out:
# {('Ramesh', 'Suresh', 'Mahesh'): 'Names'}

# %%
{['Ramesh','Suresh','Mahesh']:'Names'}
{('Ramesh','Suresh','Mahesh'):'Names'}

# %% [markdown]
# - keys are important for us
#
# - changing the keys are not allowd
#
# - lists are mutable so it is failed
#
# - tuple is immutable so it works

# %%
dict13={}

# %%
#'' [] () {}

# %%
dict14={{'Ramesh':20}:21}
dict14
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dict14={{'Ramesh':20}:21}
#       2 dict14
#
# TypeError: unhashable type: 'dict'

# %% [markdown]
# - we understood how dictinaries are working

# %% [markdown]
# - in built functions
#
# - max  min  len   sum  sorted reversed

# %%
dict1={'Ramesh':20,'Suresh':22,'Mahesh':24} # w
dict2={20:'Ramesh',22:'Suresh',24:'Mahesh'} # w
dict3={'20':'Ramesh','22':'Suresh','24':'Mahesh'} # w

# %%
len(dict1),len(dict2),len(dict3)
# Out:
# (3, 3, 3)

# %%
dict1={'Ramesh':20,'Suresh':22,'Mahesh':24}
max(dict1),min(dict1),sorted(dict1)
# keys are important
# only consider keys
# ascii values R  S  M
# R  S   M    Suresh max
# 20 22 24   Mahesh max
# Out:
# ('Suresh', 'Mahesh', ['Mahesh', 'Ramesh', 'Suresh'])

# %%
dict2={20:'Ramesh',22:'Suresh',24:'Mahesh'} # w
max(dict2),min(dict2),sorted(dict2)
# Out:
# (24, 20, [20, 22, 24])

# %%
dict3={'20':'Ramesh','22':'Suresh','24':'Mahesh'}
max(dict3),min(dict3)
# Out:
# '24'

# %%
dict1={'Ramesh':20,'Suresh':22,'Mahesh':24}
list(reversed(dict1))
# Out:
# ['Mahesh', 'Suresh', 'Ramesh']

# %%
dict1={'Ramesh':20,'Suresh':22,'Mahesh':24}
sum(dict1) # error
#sum(['R','S','M'])  # error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 dict1={'Ramesh':20,'Suresh':22,'Mahesh':24}
# ----> 2 sum(dict1)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
dict2={20:'Ramesh',22:'Suresh',24:'Mahesh'}
sum(dict2)  # sum([20,22,24])
# Out:
# 66

# %%
dict1={'Ramesh':20,'Suresh':22,'Mahesh':24}
dict2={20:'Ramesh',22:'Suresh',24:'Mahesh'}
dict1+dict2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 dict1={'Ramesh':20,'Suresh':22,'Mahesh':24}
#       2 dict2={20:'Ramesh',22:'Suresh',24:'Mahesh'}
# ----> 3 dict1+dict2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
l=[]
l.append('apple')
l.append('banana')
l
# Out:
# ['apple', 'banana']

# %%
Names = ['rakesh','suresh','sathish']
age = [20,22,41]
d={}
d['rakesh']=20
d['suresh']=23
d['sathish']=24
d={}
for i,j in zip(Names,age):
    d[i]=j
d
# Out:
# {'rakesh': 20, 'suresh': 22, 'sathish': 41}

# %% [markdown]
# **index**

# %%
s='python'
s[0]
# Out:
# 'p'

# %%
l=[10,20,30]
l[0]
# Out:
# 10

# %%
dict1={'Ramesh':20,'Suresh':22,'Mahesh':24}
dict1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 2
#       1 dict1={'Ramesh':20,'Suresh':22,'Mahesh':24}
# ----> 2 dict1[0]
#
# KeyError: 0

# %% [markdown]
# - we can not extract elements using indexing

# %%
'Ramesh':20  key:value
'Suresh':22
'Mahesh':24

# %%
'Ramesh'
# Out:
# 'Ramesh'

# %%
20
# Out:
# 20

# %%
'Ramesh':20
# Out:
#   Cell In[49], line 1
#     'Ramesh':20
#     ^
# SyntaxError: illegal target for annotation

# %%
dict1={'Ramesh':20,'Suresh':22,'Mahesh':24}
# we can extract only value by using key
dict1['Ramesh']
dict1['Suresh']
dict1['Mahesh']

# dict1[i]
# Out:
# 24

# %%
dict1={'Ramesh':20,'Suresh':22,'Mahesh':24}
for i in dict1:
    #print(i,dict1[i])
    print(f'the {i} age is {dict1[i]}')
# Out:
# the Ramesh age is 20
# the Suresh age is 22
# the Mahesh age is 24

# %% [markdown]
# **Empty string - list - dictionary analysis**

# %%
s=''
l=[]
d={}

# %%
s=s+'p'
s
# Out:
# 'p'

# %%
l.append('p')
l
# Out:
# ['p']

# %%
d={}
d['Ramesh']=20
d['Suresh']=22
d['Suresh']=24
d
# Out:
# {'Ramesh': 20, 'Suresh': 24}

# %%
d={}
d['Ramesh']=20
d['Suresh']=22
d['Mahesh']=24
d

# d[i]=j
# Out:
# {'Ramesh': 20, 'Suresh': 22, 'Mahesh': 24}

# %% [markdown]
# **list to dictionary conversion**

# %%
names=['Ramesh','Suresh','Mahesh']
age=[20,22,24]
d={}
for i,j in zip(names,age):
    d[i]=j
d
# Out:
# {'Ramesh': 20, 'Suresh': 22, 'Mahesh': 24}

# %%
numbers=[20,21,22]
#d={20:'even',21:'odd',22:'even'}
d={}
for i in numbers:
    if i%2==0:
        d[i]='even'
    else:
        d[i]='odd'
d
# Out:
# {20: 'even', 21: 'odd', 22: 'even'}

# %%
dict1={'Ramesh':20,'Suresh':22,'Mahesh':24}
keys, values = [],[]
for i in dict1:
    print(i,dict1[i])
    keys.append(i)
    values.append(dict1[i])
keys,values
# Out:
# Ramesh 20
# Suresh 22
# Mahesh 24
# (['Ramesh', 'Suresh', 'Mahesh'], [20, 22, 24])

# %%
str1='hai how are you'
str1.split()
# Out:
# ['hai', 'how', 'are', 'you']

# %%
l=['hai', 'how', 'are', 'you']
' '.join(l)
# Out:
# 'hai how are you'

# %% [markdown]
# - string to list
# - list to string
# - list to dic
# - dic to list

# %%
str1='happy happy new year year happy'
d={}
l=str1.split()
for i in l:
    if i in d:
        d[i]=d[i]+1
    else:
        d[i]=1
d
# Out:
# {'happy': 3, 'new': 1, 'year': 2}

# %% [markdown]
# **Dictionary Comprehension**

# %%
for i,j in zip(names,age):
    d[i]=j
[d[i]=j for i,j in zip(names,age)]

for i in numbers:
    if i%2==0:
        d[i]='even'
    else:
        d[i]='odd'

[d[i]='even' if i%2==0 else d[i]='odd' for i in numbers]

# %%
names=['Ramesh','Suresh','Mahesh']
age=[20,22,24]
{i:j for i,j in zip(names,age)}
# Out:
# {'Ramesh': 20, 'Suresh': 22, 'Mahesh': 24}

# %%
numbers=[20,21,22]
d={}
#[d[i]='even' if i%2==0 else d[i]='odd' for i in numbers]
{i:'even' if i%2==0 else 'odd' for i in numbers}
# Out:
# {20: 'even', 21: 'odd', 22: 'even'}

# %% [markdown]
# **Multi index**

# %%
d={'Fruites':['Apple','Banana','Cherry']}
d['Fruites'][2]
# Out:
# 'Cherry'

# %%
d={'Fruites':{'Apple':[100,200,300]}}

# %%
d
# Out:
# {'Fruites': {'Apple': [100, 200, 300]}}

# %%
len(d)
# Out:
# 1

# %%
d['Fruites']['Apple'][2]
# Out:
# 300

# %%
d={'Fruites':{'Apple':['Kashmir']}}
d['Fruites']['Apple'][0]
# Out:
# 'Kashmir'

# %%
d={'Fruites':[{'Apple':['green apple']}]}
len(d['Fruites'])
d['Fruites'][0]['Apple'][0]
# Out:
# 'green apple'

# %%
d={'Fruites':[{'Apple':[{'kashmir':[{'India':['NareshIT']}]}]}]}
len(d)
# Out:
# 1

# %%
d['Fruites'][0]['Apple'][0]['kashmir'][0]['India'][0]
# Out:
# 'NareshIT'

# %%
dir({})
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
'clear', # dic clear
'copy',  # copy
'fromkeys', # dictionary
'get',  # access
'items', # keys and values
 'keys', # only keys
 'pop', # delete
 'popitem', # dlete
 'setdefault', # default values 
 'update', # l1.extend(l2)
 'values' # only values
