# %%
# this file i opened from Home tab
# in home tab im in python_section folder

# %%
import os

# %%
os.getcwd()
# Out:
# 'F:\\Omkar\\Python'

# %%
os.getcwd()
# Out:
# 'F:\\Omkar\\Python'

# %% [markdown]
# **in build function**

# %%
# Function always with ()
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
# Function always with ()
print()
max()
min()
sum()
len()
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Function always with ()
#       2 print()
# ----> 3 max()
#       4 min()
#       5 sum()
#
# TypeError: max expected at least 1 argument, got 0

# %% [markdown]
# - whenever you miss brackets for function it will give indication
#
#         - it will display as **function**
#
#         - it will dispaly as **bound method**

# %%
l=[1,2,3,4,5]

# %%
print(l)
type(l)
max(l)
min(l)
len(l)
# Out:
# [1, 2, 3, 4, 5]
# 5

# %%
type(l)
# Out:
# list

# %%
max(l)
# Out:
# 5

# %%
sum(l)
# Out:
# 15

# %%
min(l)
# Out:
# 1

# %%
len(l)
# Out:
# 5

# %%
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 name
#
# NameError: name 'name' is not defined

# %%
name=100

# %%
n1=100
n2=200
n3=300
n4=n1+n2+n4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 n2=200
#       3 n3=300
# ----> 4 n4=n1+n2+n4
#
# NameError: name 'n4' is not defined

# %%
n1=100
n2=200
n3=300
n4=n1+n2+n3

# %%
name=100

# %%
name100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 name100
#
# NameError: name 'name100' is not defined

# %%
print()
type()
max()
min()
sum()
len()

# function
# bound method
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 print()
# ----> 2 type()
#       3 max()
#       4 min()
#
# TypeError: type() takes 1 or 3 arguments

# %% [markdown]
# - int
#
# - float
#
# - bool
#
# - str
#
# - complex
#
# - range
#
# - list
#
# - tuple
#
# - dict
#
# - set
#
# - frozenset
#
# - bytearray
#
# - bytes
#
# - memoryview

# %% [markdown]
# $integer$

# %%
num=100
print(num)
# Out:
# 100

# %%
type(num)
# Out:
# int

# %% [markdown]
# $floot$

# %%
money=500.75
type(money)
# Out:
# float

# %%
1e1
# Out:
# 10.0

# %%
1e2
# Out:
# 100.0

# %%
1e3
# Out:
# 1000.0

# %%
1e5 #1*10000
# Out:
# 100000.0

# %%
print(1e1)  #1*10
print(1e2)  #1*100
print(5e3)  #5*1000
# Out:
# 10.0
# 100.0
# 5000.0

# %%
1e+1,1e5+31,1e+5
# Out:
# (10.0, 100031.0, 100000.0)

# %%
1e-3 #1/1000
# Out:
# 0.001

# %%
10000000000000
# Out:
# 10000000000000

# %%
#ml many notations epower
520e-10   # 520/10000000000000000=0.00000000000000000520
# Out:
# 5.2e-08

# %% [markdown]
# ## String

# %%
name='python'
type(name)
# Out:
# str

# %%
city='hyderabad'
city
# Out:
# 'hyderabad'

# %%
# name : single quotes
# city : double quotes
name,city   # by default single quotes only
# Out:
# ('python', 'hyderabad')

# %%
print(name,city)
# whereever we print the answers with out quotes
# Out:
# python hyderabad

# %% [markdown]
# **tripe quotes**
#
# - triple quotes are used to write lines
#
# - if i want to write an infomation, i can use **markdown** in jupyter
#
# - but in vs code there is no markdown
#
# - then i can triple quotes to convey the informatiom
#
# - this procedure is calles as **doc string**
#
# - in prompt engineering also we will use multiple lines

# %%
"""today im learning python type
these are very easy"""
# Out:
# 'today im learning python type\nthese are very easy'
