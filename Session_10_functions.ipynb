# %% [markdown]
# ## Functions

# %%
- Block of code we can use mutiple times

- reuse of code lines

# %%
Salary=eval(input('enter the salary:'))
tax_per=eval(input('enter the tax_per:'))
tax=Salary*tax_per/100
print(f'the tax_amount is: {tax}')
# Out:
# enter the salary: 100000
# enter the tax_per: 10
# the tax_amount is: 10000.0

# %%
# how many lines of code: 4
# how many employees : 400
# if no function concept i need to use 4 lines for 400 members 
# total how many lines : 1600

# %% [markdown]
# - functions with out arguments
#
# - functions with arguments
#
# - functions with defualt arguments
#
# - functions which has local and global variables
#
# - function with return statemens
#
# - functions in functions
#
# - functions with keywordarguments:kwargs

# %%
def <FUNCTION NAME>():
    <write line>

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
def add():
    a=10
    b=20
    c=a+b
    print(c)

# %%
add()
# Out:
# 30

# %%
import random

# %%
random.randint(1,10)
# Out:
# 3

# %%
import random
random.randint(1,10)
# Out:
# 1

# %%
def tax_calculation():
    Salary=eval(input('enter the salary:'))
    tax_per=eval(input('enter the tax_per:'))
    tax=Salary*tax_per/100
    print(f'the tax_amount is: {tax}')

tax_calculation()
# Out:
# enter the salary: 10000
# enter the tax_per: 10
# the tax_amount is: 1000.0

# %% [markdown]
# - First define the function then call the function
#
# - function name has same rules as variable name rules
#
# - function name should not be any variable we are using inside the function
#
#     - in above code we have a variable called **tax**
#
#     - function name should not be **tax**
#
# - function names should not be any pacakge or module or attribute name
#
# - function names should not be yourfile name
#
# - function name should not be any inbuilt function
#
# - **DONT CONFUSE PYTHON BY PROVIDING SAME NAMES , EACH FUNCTION SHOULD BE DIFFERENT NAME**

# %%
def addition():
    n1=eval(input('enter the number1:'))
    n2=eval(input('enter the number2:'))
    Sum=n1+n22
    print(Sum)

# %%
addition()
# Out:
# enter the number1: 10
# enter the number2: 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 addition()
#
# Cell In[24], line 4, in addition()
#       2 n1=eval(input('enter the number1:'))
#       3 n2=eval(input('enter the number2:'))
# ----> 4 Sum=n1+n22
#       5 print(Sum)
#
# NameError: name 'n22' is not defined

# %%
# wap ask the user take two number print subtraction multiplication and division
# wap ask the user take the radius find the area of circle
    # pi=3.14
    # r=100
   # area_of_circle=pi*r*r

# wap ask the user take height and breadth find the area of traingle
#       area_of_traingle=0.5*b*h

# wap ask the user take 3 numbers find the average
# wap ask the user take the bill amount and tip amount calculate total bill
# wap ask the user take the salary, percetage of tax calculate tax amount
# wap ask the user take the value in dollar convert into rupees
#         1$=80rs
# wap ask the use take weight in kgs convert into pounds
#     1kg=2.2pounds

# %%
def addition1():
    n1=eval(input('Plz Enetr the first Number'))
    n2=eval(input('Plz Enetr the second Number'))
    Sum=n1+n22
    print(sum)

# %%
addition1()
# Out:
# Plz Enetr the first Number 10
# Plz Enetr the second Number 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 addition1()
#
# Cell In[30], line 4, in addition1()
#       2 n1=eval(input('Plz Enetr the first Number'))
#       3 n2=eval(input('Plz Enetr the second Number'))
# ----> 4 sum=n1+n22
#       5 print(sum)
#
# NameError: name 'n22' is not defined

# %%
def average():
    n1=eval(input('Plz Enetr the first Number'))
    n2=eval(input('Plz Enetr the second Number'))
    n3=eval(input('Plz Enetr the second Number'))
    avg=(n1+n2+n3)/3
    avg1=round(avg,2)
    print(avg1)

average()
# Out:
# Plz Enetr the first Number 10
# Plz Enetr the second Number 21
# Plz Enetr the second Number 33
# 21.33

# %%
def tip_amount_cal():
    bill_Amount=eval(input('Plz Enetr the bill_Amount'))
    tip_per=eval(input('Plz Enetr the tip_per'))
    tip_amount=bill_Amount*tip_per/100
    total_bill=bill_Amount+tip_amount
    print(total_bill)

# %%
tip_amount_cal()
# Out:
# Plz Enetr the bill_Amount 10000
# Plz Enetr the tip_per 10
# 11000.0

# %%
def addition3():
    n1=eval(input('Plz Enetr the first Number'))
    n2=eval(input('Plz Enetr the second Number'))
    Sum=n1+n22
    print(Sum)

# %%
try:
    def addition3():
        n1=eval(input('Plz Enetr the first Number'))
        n2=eval(input('Plz Enetr the second Number'))
        Sum=n1+n22
        print(Sum)
except Exception as e:
    print(e)

# %%
addition3()
# Out:
# Plz Enetr the first Number 10
# Plz Enetr the second Number 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 addition3()
#
# Cell In[40], line 5, in addition3()
#       3 n1=eval(input('Plz Enetr the first Number'))
#       4 n2=eval(input('Plz Enetr the second Number'))
# ----> 5 Sum=n1+n22
#       6 print(Sum)
#
# NameError: name 'n22' is not defined

# %%
def addition4():
    try:
        n1=eval(input('Plz Enetr the first Number'))
        n2=eval(input('Plz Enetr the second Number'))
        Sum=n1+n22
        print(Sum)
    except Exception as e:
        print(e)

# %%
addition4()
# Out:
# Plz Enetr the first Number 10
# Plz Enetr the second Number 20
# name 'n22' is not defined

# %%
def area_of_circle():
    pi=3.14
    radius=eval(input('enter the radius'))
    area=pi*radius*radius
    print(f'the area of circle is:{area}')

def average():
    n1=eval(input('Plz Enetr the first Number'))
    n2=eval(input('Plz Enetr the second Number'))
    n3=eval(input('Plz Enetr the second Number'))
    avg=(n1+n2+n3)/3
    avg1=round(avg,2)
    print(avg1)


def tip_amount_cal():
    bill_Amount=eval(input('Plz Enetr the bill_Amount'))
    tip_per=eval(input('Plz Enetr the tip_per'))
    tip_amount=bill_Amount*tip_per/100
    total_bill=bill_Amount+tip_amount
    print(total_bill)

def Tax_cal():
    salary=eval(input('enter the salary:'))
    tax_per=eval(input('Tax per:'))
    tax=salary*tax_per/100
    print(f'the tax amount for {salary} is {tax}')

# %%
area_of_circle()
print()
average()
print('=======================================')
tip_amount_cal()
print('****************************************')
Tax_cal()
# Out:
# enter the radius 100
# the area of circle is:31400.0
# Plz Enetr the first Number 10
# Plz Enetr the second Number 20
# Plz Enetr the second Number 30
# 20.0
# ...
# Plz Enetr the bill_Amount 10000
# Plz Enetr the tip_per 10
# 11000.0
# ****************************************
# enter the salary: 100000
# Tax per: 10
# the tax amount for 100000 is 10000.0

# %%
area_of_circle()  # No arguments/parameters
average()         # No argumenst/parameters 
tip_amount_cal()  # No arguments/paramteres
Tax_cal()         # No arguments/parameters

# %%
import random
random.random(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 import random
# ----> 2 random.random(10)
#
# TypeError: Random.random() takes no arguments (1 given)

# %%
random.randint()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 random.randint()
#
# TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'

# %%
area_of_circle(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 area_of_circle(100)
#
# TypeError: area_of_circle() takes 0 positional arguments but 1 was given

# %%
def area_of_circle1():
    """
    this function find area of circle
    """
    pi=3.14
    radius=eval(input('enter the radius'))
    area=pi*radius*radius
    print(f'the area of circle is:{area}')

# %% [markdown]
# **Function with arguments**
#
# - Below average codee how many variable are available: 5
#
# - How many input variables : 3 n1,n2,n3
#
# - How many output variables : 2  avg and avg1
#
# - DO NOT TOUCH OUTPUT VARIABLES

# %%
def average1(n1,n2,n3):
    print('n1:',n1)
    print('n2:',n2)
    print('n3:',n3)
    avg=(n1+n2+n3)/3
    avg1=round(avg,2)
    print(avg1)

# %%
average1(10,20,30)
# Out:
# n1: 10
# n2: 20
# n3: 30
# 20.0

# %%
def area_of_circle2(pi,radius):
    """
    this function find area of circle
    """
    area=pi*radius*radius
    print(f'the area of circle is:{area}')

# %%
area_of_circle2(3.14,100)
# Out:
# the area of circle is:31400.0

# %% [markdown]
# **Default arguments**
#
# - Below code we have n1,n2,n3 are input varaibles
#
# - now we can fix some values
#
# - so no need to provide explicitly
#
# - n1 and n2 are argumnets
#
# - n3 no need provide by defualt n3=30
#
# - if you provide it will take new value

# %%
def average2(n1,n2,n3=30):
    print('n1:',n1)
    print('n2:',n2)
    print('n3:',n3)
    avg=(n1+n2+n3)/3
    avg1=round(avg,2)
    print(avg1)

average2(10,20)
average2(10,20,30)
# Out:
# n1: 10
# n2: 20
# n3: 30
# 20.0
# n1: 10
# n2: 20
# n3: 30
# 20.0

# %%
def average3(n1,n2=30,n3):
    print('n1:',n1)
    print('n2:',n2)
    print('n3:',n3)
    avg=(n1+n2+n3)/3
    avg1=round(avg,2)
    print(avg1)

average3(10,20)
# Out:
#   Cell In[54], line 1
#     def average3(n1,n2=30,n3):
#                           ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
def average4(n1,n3,n2=30):
    print('n1:',n1)
    print('n2:',n2)
    print('n3:',n3)
    avg=(n1+n2+n3)/3
    avg1=round(avg,2)
    print(avg1)

average4(10,20)
# Out:
# n1: 10
# n2: 30
# n3: 20
# 20.0

# %% [markdown]
# **DEFUALT ARGUMENTS SHOULD BE AT LAST**

# %%
def average5(<values>):
    avg=(n1+n2+n3)/3
    avg1=round(avg,2)
    print(avg1)
    
average5(n1,n2,n3=10)  # c
average5(n1,n2=10,n3)  # fail
average5(n1=10,n2,n3) # fail
average5(n1,n2=10,n3=20) # c
average5(n1=10,n2,n3=10) # fail
average5(n1=10,n2=10,n3) # fail
average5(n1=10,n2=20,n3=30) # c
average5(n1,n2,n3) # c
average5() # fail

# %%
def average5():
    avg=(n1+n2+n3)/3
    avg1=round(avg,2)
    print(avg1)

average5()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 6
#       3     avg1=round(avg,2)
#       4     print(avg1)
# ----> 6 average5()
#
# Cell In[59], line 2, in average5()
#       1 def average5():
# ----> 2     avg=(n1+n2+n3)/3
#       3     avg1=round(avg,2)
#       4     print(avg1)
#
# NameError: name 'n1' is not defined

# %%
def addition(n1,n2,n3=300):
    summ=n1+n2+n3
    print(summ)
addition(100,200)
# Out:
# 600

# %%
def addition1(n1,n2,n3=300):
    summ=n1+n2+n3
    print(summ)
addition1(100,200,400)
# Out:
# 700

# %%
def addition1(n1,n2,n3=300):
    summ=n1+n22+n3
    print(summ)
############ Define the function ################
addition1(10,20)  # call the function

summ=n1+n22+n3
print(summ)

# %%
# First define the function n3=300
# call the function  400
# the lines inside function will process 500

# %%
def addition2(n1,n2,n3=300):
    n3=500
    summ=n1+n2+n3
    print(summ)
addition2(100,200,400)
# Out:
# 800

# %%
def addition3(n1,n2,n3=300):
    n3=500
    summ=n1+n2+n3
    print(summ)
n3=600
addition3(100,200,400)

# 300 ====>600 ===> 400 ===> 500
# Out:
# 800

# %%
a=10
print('hello')
b=20

# %%
def addition4(n1,n2,n3=300):
    summ=n1+n2+n3
    print('summ:',summ)
n3=700
addition4(100,200)

# 300 ====>600
# Out:
# summ: 600

# %%
def addition5(n1,n2):
    n3=600  # local
    summ=n1+n2+n3
    print('summ:',summ)
#addition5(100,200)   # error  we want n3
#addition5(100,200,300) # error n1 and n2
addition5(100,200)

# 300 ====>600
# Out:
# summ: 900

# %%
n3=700  # global
def addition6(n1,n2):
    summ=n1+n2+n3
    print('summ:',summ)
#addition5(100,200)   # error  we want n3
#addition5(100,200,300) # error n1 and n2
addition6(100,200)

# 300 ====>600
# Out:
# summ: 1000

# %% [markdown]
# - Functions with out arguments
#
# - Functions with arguments
#
# - Functions with defaualt arguments

# %% [markdown]
# **local vs global variables**

# %%
n1=eval(input('enter a number1:'))
n2=eval(input('enter a number2:'))
n3=eval(input('enter a number3:'))
summ=n1+n2+n3
print(f'the sum of {n1},{n2} and {n3} are:{summ}')
# Out:
# enter a number1: 20
# enter a number2: 22
# enter a number3: 23
# the sum of 20,22 and 23 are:65

# %%
def addition1():
    n1=eval(input('enter a number1:'))
    n2=eval(input('enter a number2:'))
    n3=eval(input('enter a number3:'))
    summ=n1+n2+n3
    print(f'the sum of {n1},{n2} and {n3} are:{summ}')

def addition2(n1):
    n2=eval(input('enter a number2:'))
    n3=eval(input('enter a number3:'))
    summ=n1+n2+n3
    print(f'the sum of {n1},{n2} and {n3} are:{summ}')

def addition3(n1,n2):
    n3=eval(input('enter a number3:'))
    summ=n1+n2+n3
    print(f'the sum of {n1},{n2} and {n3} are:{summ}')

def addition4(n1,n2,n3):
    summ=n1+n2+n3
    print(f'the sum of {n1},{n2} and {n3} are:{summ}')

def addition5(n1,n2,n3=10):
    summ=n1+n2+n3
    print(f'the sum of {n1},{n2} and {n3} are:{summ}')

def addition6(n1,n2=20,n3=10):
    summ=n1+n2+n3
    print(f'the sum of {n1},{n2} and {n3} are:{summ}')

def addition7(n1=10,n2=20,n3=30):
    summ=n1+n2+n3
    print(f'the sum of {n1},{n2} and {n3} are:{summ}')

# %%
addition1()
addition2(n1=20)  # we can provide the value using argument name
addition3(n1=20,n2=30)
addition3(n2=20,n1=30)
addition3(10,100)
addition4(n1=10,n2=20,n3=30)
addition4(30,20,10)
addition5(30,50)
addition6(30)
addition7()
# Out:
# enter a number1: 40
# enter a number2: 50
# enter a number3: 60
# the sum of 40,50 and 60 are:150
# enter a number2: 70
# enter a number3: 70
# the sum of 20,70 and 70 are:160
# enter a number3: 60
# the sum of 20,30 and 60 are:110
# enter a number3: 70
# the sum of 30,20 and 70 are:120
# the sum of 10,20 and 30 are:60
# the sum of 30,20 and 10 are:60
# the sum of 30,50 and 10 are:90
# the sum of 30,20 and 10 are:60
# the sum of 10,20 and 30 are:60

# %%
addition3(n1=20,n2=30)   # n1=20  n2=30
addition3(n2=100,n1=10)  # n2=100  n1=10
addition3(10,100)  # go with order

# If you are not changing the order you can provide direct values
# suppose you are changing the order then provide values using argument name

# %% [markdown]
# - local variable means
#
# - the variables which are used inside function
#
# - these variables are can not use outside the function

# %%
def addition8():
    N1=100
    N2=200
    N3=300
    Summ=N1+N2+N3
    print(f'the sum of {N1},{N2} and {N3} are:{Summ}')

print(f'the sum of {N1},{N2} and {N3} are:{Summ}')


#  n1   n2   n3  summ 
# inside function : local variabe

# %%
addition8()
# Out:
# the sum of 100,200 and 300 are:600

# %%
Summ
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 Summ
#
# NameError: name 'Summ' is not defined

# %%
N1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 N1
#
# NameError: name 'N1' is not defined

# %%
Mahesh babu   Telugu states 
Outside telugu === local varaible

Prabhas  
PAN India in entire India: Global variable

# %%
N1=100
N2=200
N3=300

def addition9():
    Summ=N1+N2+N3
    print(f'the sum of {N1},{N2} and {N3} are:{Summ}')

addition9()
# Out:
# the sum of 100,200 and 300 are:600

# %%
N1,N2,N3
# Out:
# (100, 200, 300)

# %%
a=10

def addition10():
    Summ=a+b+c
    print(f'the sum of {a},{b} and {c} are:{Summ}')
b=20
c=30
addition10()
# Out:
# the sum of 10,20 and 30 are:60

# %%
a=10
# define the function scanning done a,b,c  a=10
b=20
c=30
addition()
Summ=a+b+c
print(f'the sum of {a},{b} and {c} are:{Summ}')

# %%
a=10
def addition10():
    a=100
    Summ=a+b+c
    print(f'the sum of {a},{b} and {c} are:{Summ}')
b=20
c=30
addition10()

# a=10
# def
# b=20
# c=30
# call
# running a=100
# 100+20+30
# Out:
# the sum of 100,20 and 30 are:150

# %% [markdown]
# **SPL CASE**

# %%
a=10
def addition10():
    Summ=a+b+c
    a=100
    print(f'the sum of {a},{b} and {c} are:{Summ}')
b=20
c=30
addition10()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[40], line 8
#       6 b=20
#       7 c=30
# ----> 8 addition10()
#
# Cell In[40], line 3, in addition10()
#       2 def addition10():
# ----> 3     Summ=a+b+c
#       4     a=100
#       5     print(f'the sum of {a},{b} and {c} are:{Summ}')
#
# UnboundLocalError: cannot access local variable 'a' where it is not associated with a value

# %%
def addition10():
    Summ=aa+bb+cc
    aa=100
    print(f'the sum of {aa},{bb} and {cc} are:{Summ}')
bb=20
cc=30
addition10()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[43], line 7
#       5 bb=20
#       6 cc=30
# ----> 7 addition10()
#
# Cell In[43], line 2, in addition10()
#       1 def addition10():
# ----> 2     Summ=aa+bb+cc
#       3     aa=100
#       4     print(f'the sum of {aa},{bb} and {cc} are:{Summ}')
#
# UnboundLocalError: cannot access local variable 'aa' where it is not associated with a value

# %%
aa=200
def addition10(aa=100):
    Summ=aa+bb+cc
    print(f'the sum of {aa},{bb} and {cc} are:{Summ}')
bb=20
cc=30
addition10()

# 200 ==== define 100 === b20  c30  call === runn
# Out:
# the sum of 100,20 and 30 are:150

# %%
aa=200
def addition10(aa=100):
    Summ=aa+bb+cc
    print(f'the sum of {aa},{bb} and {cc} are:{Summ}')
bb=20
cc=30
addition10(aa=500)

# 200 === 100== b20  c30 == 500
# Out:
# the sum of 500,20 and 30 are:550

# %%
aa=200
def addition10(aa=100):
    aa=800
    Summ=aa+bb+cc
    print(f'the sum of {aa},{bb} and {cc} are:{Summ}')
bb=20
cc=30
addition10(aa=500)
# aa=200
# def  aa=100
# bb20  cc30
# call aa=500
# aa=800
# Out:
# the sum of 800,20 and 30 are:850

# %%
aa=200
def addition10(aa=100):
    aa=800
    Summ=aa+bb+cc
    print(f'the sum of {aa},{bb} and {cc} are:{Summ}')
bb=20
cc=30
aa=900
addition10(aa=500)
# aa=200
# def  aa=100
# bb20  cc30
# call aa=500
# aa=800
# Out:
# the sum of 800,20 and 30 are:850

# %%
aa=200
def addition10(aa=100):
    aa=800
    Summ=aa+bb+cc
    aa=1000
    print(f'the sum of {aa},{bb} and {cc} are:{Summ}')
bb=20
cc=30
aa=900
addition10(aa=500)
# aa=200
# def  aa=100
# bb20  cc30
# call aa=500
# aa=800
# Out:
# the sum of 1000,20 and 30 are:850

# %%
a=10
def addition10():
    Summ=a+b+c
    print(f'the sum of {a},{b} and {c} are:{Summ}')
b=20
c=30
addition10()   # 60
############################################################
a=10
def addition10():
    a=100
    Summ=a+b+c
    print(f'the sum of {a},{b} and {c} are:{Summ}')
b=20
c=30
addition10()  # 150
#############################################################
aa=200
def addition10(aa=100):
    Summ=aa+bb+cc
    print(f'the sum of {aa},{bb} and {cc} are:{Summ}')
bb=20
cc=30
addition10()  #  150

# 200 ==== define 100 === b20  c30  call === runn
##############################################################
aa=200
def addition10(aa=100):
    Summ=aa+bb+cc
    print(f'the sum of {aa},{bb} and {cc} are:{Summ}')
bb=20
cc=30
addition10(aa=500) 

#  500

#######################################################
aa=200
def addition10(aa=100):
    aa=800
    Summ=aa+bb+cc
    print(f'the sum of {aa},{bb} and {cc} are:{Summ}')
bb=20
cc=30
addition10(aa=500)
# aa=200
# def  aa=100
# bb20  cc30
# call aa=500
# aa=800

aa=200
def addition10(aa=100):
    aa=800
    Summ=aa+bb+cc
    print(f'the sum of {aa},{bb} and {cc} are:{Summ}')
bb=20
cc=30
aa=900
addition10(aa=500)
# aa=200
# def  aa=100
# bb20  cc30
# call aa=500
# aa=800

# %%
aa=200
def addition10(aa=100):
    Summ=aa+bb+cc
    print(f'the sum of {aa},{bb} and {cc} are:{Summ}')
bb=20
cc=30
addition10(aa=500) 

# aa=200  
# define addition10(aa=100)  aa=100
#bb=20
# cc=30
# addition10(aa=500)    aa=500
# Summ=aa+bb+cc

# %%
aa=200
def addition10(aa=100):
    aa=800
    Summ=aa+bb+cc
    print(f'the sum of {aa},{bb} and {cc} are:{Summ}')
bb=20
cc=30
aa=900
addition10(aa=500)
# 200===100==900===500===800

# %%
aa=200
def addition10(aa=100):
    aa=800
    Summ=aa+bb+cc
    aa=1000
    print(f'the sum of {aa},{bb} and {cc} are:{Summ}')
bb=20
cc=30
aa=900
addition10(aa=500)

# 200 === 100 ===900 == 500 === 800 === 1000

# %% [markdown]
# **unbound local error**

# %%
s=10
add=s+10
add 
################################
add=S+10
S=10   # Name error

# %%
def f1():
    add=S+10
    S=10   # Name error
f1()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[59], line 4
#       2     add=S+10
#       3     S=10   # Name error
# ----> 4 f1()
#
# Cell In[59], line 2, in f1()
#       1 def f1():
# ----> 2     add=S+10
#       3     S=10
#
# UnboundLocalError: cannot access local variable 'S' where it is not associated with a value

# %%
- Python scan the function No running only scanning

- Python sees  

    - add=S+10

    - S is decalred

- add and S are local variables

- I need S value to do this

- Even though the same variable globally declare also I will not consider that

# %%
S=100
def f2():  # Rameh
    add=S+10 # S+10
    S=10   # S later  2 line there is error 
f2()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[62], line 5
#       3     add=S+10
#       4     S=10   # Name error
# ----> 5 f2()
#
# Cell In[62], line 3, in f2()
#       2 def f2():
# ----> 3     add=S+10
#       4     S=10
#
# UnboundLocalError: cannot access local variable 'S' where it is not associated with a value

# %%
S=100
def f2():  # Rameh
    S=100
    add=S+10 # S+10
    S=100
S=100     
f2()

# %%
S=100  # global variable
def f1():
    add=S+10 #  100+10 =  feeling 
S=100
f1()

f1 scanning starts
add=S+10  Scanning
S=10     Scanning these two lines seeing

1) Error   2) No error
function undesrand that it is a error
add=S+10
S=10 


f1 scanning starts
add=S+10  Scanning
where is  S?

S=10     S=10 scann
add=S+10  add scann  20

# %%
aa=200
def addition10(aa=100):
    aa=800
    Summ=aa+bb+cc
    print(f'the sum of {aa},{bb} and {cc} are:{Summ}')
bb=20
cc=30
addition10(aa=500)

# %%
def f2():  
    S=100
    add=S+10
f2()    # answer

def f2():  
    add=S+10
    S=100
f2()       # error


def f2():  
    add=S+10
f2()       # error
S=100

# %%
S=100
def f2():  
    add=S+10
    S=100
f2()       # error

# %% [markdown]
# **How can we use local variable outside the function**

# %%
def addition10():
    global add1
    aa=100
    bb=200
    cc=300
    add1=aa+bb+cc
    print(f'the sum of {aa},{bb} and {cc} are:{add1}')

addition10()
# Out:
# the sum of 100,200 and 300 are:600

# %%
add1
# Out:
# 600

# %%
def math_fun():
    global add, sub
    n1=evel(input('enter a number')
    n2=evel(input('enter a number')        
    add = n1+n2
    sub = n1-n2
    print(f'the sum of {n1},{n2} are:{add}')
     print(f'the sum of {n1},{n2} are:{sub}')

math_fun()

# %% [markdown]
# **return statement**

# %% [markdown]
# - as of now we just print the outputs but we are not storng
#
# - return is a keyword is used to store the output
#
# - some one is returning some thing to me
#
# - function is returning the output to me
#
# - in above example there are two output add,sub
#
# - which means function is trying to return these output
#
# - i need to store using return value

# %%
def math_fun1():
    n1=eval(input('enter a number'))
    n2=eval(input('enter a number'))       
    add = n1+n2 #local
    sub = n1-n2 #local
    print(f'the sum of {n1},{n2} are:{add}')
    print(f'the sum of {n1},{n2} are:{sub}')
    return(add)

# %%
virat=math_fun1() # 300
ADD=math_fun1()   #500
add=math_fun1()   # prefer 3000
# ADD=300 (brain)
# Out:
# enter a number 100
# enter a number 200
# the sum of 100,200 are:300
# the sum of 100,200 are:-100
# enter a number 100
# enter a number 200
# the sum of 100,200 are:300
# the sum of 100,200 are:-100
# enter a number 1000
# enter a number 5000
# the sum of 1000,5000 are:6000
# the sum of 1000,5000 are:-4000

# %%
def math_fun2():
    n1=eval(input('enter a number'))
    n2=eval(input('enter a number'))       
    Add = n1+n2 #local
    Sub = n1-n2 #local
    print(f'the sum of {n1},{n2} are:{Add}')
    print(f'the sum of {n1},{n2} are:{Sub}')
    return(Add,Sub)

output=math_fun2() # two value save in tuple
Add,Sub=math_fun2() # two value in different variables
Sub,Add1=math_fun2()  # two value but wringly saving
# Out:
# enter a number 100
# enter a number 200
# the sum of 100,200 are:300
# the sum of 100,200 are:-100
# enter a number 1000
# enter a number 2000
# the sum of 1000,2000 are:3000
# the sum of 1000,2000 are:-1000
# enter a number 1
# enter a number 2
# the sum of 1,2 are:3
# the sum of 1,2 are:-1

# %%
output
# Out:
# (300, -100)

# %%
Add
# Out:
# 3000

# %%
Sub
# Out:
# 3

# %%
Add1
# Out:
# -1

# %%
def greet1(name,age):
    print(f"hello my name is:{name} and age is:{age}")

# %%
greet1('python',10)
# Out:
# hello my name is:python and age is:10

# %%
greet1(name='python',10)
# default parameter concept
# default argument should be at last
# Out:
#   Cell In[19], line 1
#     greet1(name='python',10)
#                            ^
# SyntaxError: positional argument follows keyword argument

# %%
greet1('python',age=10)
# Out:
# hello my name is:python and age is:10

# %%
greet1(name='python',age=10)
# Out:
# hello my name is:python and age is:10

# %% [markdown]
# **position only arguments**
#
# - slash left side position are fixed
#
# - no need to call them with their name

# %%
def greet2(name,/,age):
    print(f"hello my name is:{name} and age is:{age}")

# %%
greet2('python',10)
# Out:
# hello my name is:python and age is:10

# %%
greet2(name='python',10)
# Out:
#   Cell In[24], line 1
#     greet2(name='python',10)
#                            ^
# SyntaxError: positional argument follows keyword argument

# %%
greet2('python',age=10)
# Out:
# hello my name is:python and age is:10

# %%
greet2(name='python',age=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 greet2(name='python',age=10)
#
# TypeError: greet2() got some positional-only arguments passed as keyword arguments: 'name'

# %%
<left>/<right>

DO NO GIVE VARIABLES NAME SLASH LEFT SIDE

# %%
import math
math.pow(2,3) # w
math.pow(x=2,y=3) #f
math.pow(2,y=3) # f

# %%
def greet3(name,*,age):
    print(f"hello my name is:{name} and age is:{age}")

# %%
greet3('python',10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 greet3('python',10)
#
# TypeError: greet3() takes 1 positional argument but 2 were given

# %%
greet3(name='python',10)
# Out:
#   Cell In[34], line 1
#     greet3(name='python',10)
#                            ^
# SyntaxError: positional argument follows keyword argument

# %%
greet3('python',age=10)
# Out:
# hello my name is:python and age is:10

# %%
greet3(name='python',age=10)
# Out:
# hello my name is:python and age is:10

# %%
after * mandatory to provide argument name
after / optional to provide argument name

before * optional to provide argument name
before / do not provide the argument name

# %%
def avg(a,b,c):
    avg1=(a+b+c)/3
    print(avg1)

# %%
avg(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 avg(1)
#
# TypeError: avg() missing 2 required positional arguments: 'b' and 'c'

# %%
avg(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 avg(1,2)
#
# TypeError: avg() missing 1 required positional argument: 'c'

# %%
avg(1,2,3)
# Out:
# 2.0

# %% [markdown]
# **args**
#
# - we can provide many argument as a tuple
#
# - in down we provide 1,2,3 total 3 values as a tuple
#
# - that tuple name is args
#
# - args=(1,2,3)
#
# - insteard of provide a,b,c 3 names we are passing 3 value

# %%
def avg(*args):
    print(args)
    avg1=sum(args)/3
    print(avg1)
    
avg(1,2,3)
# Out:
# (1, 2, 3)
# 2.0

# %%
def avg():
    a=10
    b=20
    c=30
    avg1(a+b+c)/3
    print(avg1)

def avg():
    Value = 10,20,30
    avg1=sum(Value)/3
    print(avg1)

def avg(*args):
    avg1=sum(args)/len(args)
    print(avg1)

avg(10,20,30,40,50,60,70)
# Out:
# 40.0
