# %% [markdown]
# - try and except is used to catch the errors
#
# - try and except is used to handle the errors
#
# - try and except is called as Exception handling mechanism
#
# - In python we will get errors , some time that errors not important
#
# - but when error comes python execustion will stop
#
# - try and except designed such a way that, even though we got the error the execution will not stop
#
# - original code block will be under **try block**
#
# - error handling code will be available in **except block**

# %%
a=10   # c
print(a) # c
b=20  # c
print(b) # c
c=b+a  # w  d
print('hello') # c
# Out:
# 10
# 20
# hello

# %%
import os
os.makedirs('try')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[3], line 2
#       1 import os
# ----> 2 os.makedirs('try')
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'try'

# %%
print('hai')

# %% [markdown]
# **name error**

# %%
omkar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 omkar
#
# NameError: name 'omkar' is not defined

# %% [markdown]
# **type error**

# %%
'a'+10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 'a'+10
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# **zero division error**

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %%
0/10
# Out:
# 0.0

# %% [markdown]
# **module not found error**

# %%
import virat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import virat
#
# ModuleNotFoundError: No module named 'virat'

# %% [markdown]
# **attribute error**

# %%
import random
random.virat
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 2
#       1 import random
# ----> 2 random.virat
#
# AttributeError: module 'random' has no attribute 'virat'

# %% [markdown]
# **value error**

# %%
int('10.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 int('10.5')
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
#12345 === 54321

int(str(12345)[::-1])
# Out:
# 54321

# %% [markdown]
# - Name error
#
# - Type error
#
# - Value error
#
# - Module not found error
#
# - attribute error
#
# - zero division error

# %%
try:
    a=10
    b=20
    c=a+b
    print(f"the addition of {a} and {b} is:{c}")

except:
    print('Hello bro error agaya thats im agaya')
# Out:
# the addition of 10 and 20 is:30

# %%
try:
    a=10
    print(a)
    b=0
    print(b)
    c=a/b
    print(f"the addition of {a} and {b} is:{c}")

except:
    print('Hello bro error agaya thats im agaya')
# Out:
# 10
# 0
# Hello bro error agaya thats im agaya

# %%
try:
    num1=eval(input('enter the number1:'))
    num2=eval(input('enter the number2:'))
    avg=(num1+num2)/2
    print(f'the avg of {num1} and {num2} is:{avg}')
except Exception as e:
    print(e)
# Out:
# enter the number1: 10
# enter the number2: 20
# the avg of 10 and 20 is:15.0

# %%
try:
    num1=eval(input('enter the number1:'))
    num2=eval(input('enter the number2:'))
    avg=(num1+num2)/0
    print(f'the avg of {num1} and {num2} is:{avg}')
except Exception as e:
    print(e)
    print('ha ha ')
# Out:
# enter the number1: 10
# enter the number2: 20
# division by zero
# ha ha

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %%
try:
    omkar
except Exception as e:
    print(e)
# Out:
# name 'omkar' is not defined

# %% [markdown]
# **Syntax errors will not catch**

# %%
try:
    num1=eval(input('enter the number1:')
    num2=eval(input('enter the number2:'))
    avg=(num1+num2)/2
    print(f'the avg of {num1} and {num2} is:{avg}')
except Exception as e:
    print(e)
# Out:
#   Cell In[45], line 2
#     num1=eval(input('enter the number1:')
#              ^
# SyntaxError: '(' was never closed

# %%
#sir can you explain attribute error
import random
try:
    random.randintt(1,10)
except Exception as e:
    print(e)
# Out:
# module 'random' has no attribute 'randintt'

# %%
import randomm
try:
    random.randintt(1,10)
except Exception as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 import randomm
#       2 try:
#       3     random.randintt(1,10)
#
# ModuleNotFoundError: No module named 'randomm'

# %%
try:
    import randomm
    random.randintt(1,10)
except Exception as e:
    print(e)
# Out:
# No module named 'randomm'

# %%
num=eval(input('enter number:'))
if num%2==0:
    print(f'the {num} is an even')
else:
    print(f'the {num} is an odd')
# Out:
# enter number: 290
# the 290 is an even

# %%
try:
    try:
        num=eval(input('enter number:'))  # 100
    except Exception as teja:
        print(teja)
    if num%2==0:  #  100%2
        print(f'the {num} is an even')
    else:
        print(f'the {num} is an odd')
except Exception as e:
    print(e)
# Out:
# enter number: apple
# name 'apple' is not defined
# the 100 is an even

# %% [markdown]
# **finally block**

# %% [markdown]
# - **try** block is used to run original code or correct code
#
# - **except** block is used to catch the errors mainly
#
# - in colud whenever we establish a connection money deduction starts
#
# - even for correct code or wrong code the money deducton start when connenction establish
#
# - so it is very important we need to close the connection
#
# - in that sitution we will use **finally** block
#
# - if try block executes entirely after finally block also execute
#
# - if except block executes entirely after finally block also execute

# %%
try:
    a=10
    b=20
    c=a/0
    print(f"the addition of {a} and {b} is:{c}")

except:
    print('Hello bro error agaya thats im agaya')

finally:
    print('bye')
# Out:
# Hello bro error agaya thats im agaya
# bye

# %%
till all the codes
with try-except
