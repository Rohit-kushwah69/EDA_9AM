# %% [markdown]
# **input**

# %%
a=10

# %%
input()
# Out:
#  50
# '50'

# %% [markdown]
# # input()
# input()
# input()

# %%
n1=input('enter a value:')
name=input('enter a name:')
# Out:
# enter a value: 500
# enter a name: rohit singh

# %%
n1,name
# Out:
# ('500', 'rohit singh')

# %%
n1=input('enter n1:')  # '100'
n2=input('enter n2:')  # '200'
n1+n2
# Out:
# enter n1: 100
# enter n2: 200
# '100200'

# %%
'100'+'200'
# Out:
# '100200'

# %%
n1=int(input('enter a number'))
n2=int(input('enter a number'))
n1+n2
# Out:
# enter a number 200
# enter a number 200
# 400

# %%
n1=input('enter a value')
n2=input('enter a value')
int(n1)+int(n2)
# Out:
# enter a value 100
# enter a value 200
# 300
