# %%
import addition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import addition
#
# ModuleNotFoundError: No module named 'addition'

# %%
import random

# %%
import virat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import virat
#
# ModuleNotFoundError: No module named 'virat'

# %%
import time

# %%
import pandas

# %%
import math

# %%
import os

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# step-1: import <module name> 
import random 
# step -2 dir(<modulename>)
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
# step-2 import <module name>
# step-2 dir <modelname>
#       sirectory will display all the attribute names
# step-3 modulename.attiribute
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x00000292129892F0>>

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
math.pi
# Out:
# 3.141592653589793

# %%
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x00000292129892F0>>

# %%
# step-1 import <module name>
# step-2 dir(<module name>)
# step-3 modulename.attribute name [direct vs bound]
# step-4 help(modulename.attributename)
#apply the use case

# module name: random
# attribute randint

# %%
import random

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x00000292129892F0>>

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(1,10)
# Out:
# 5

# %%
# module: random
# attribute: randint

# module: random
# attribute: random

# module: random
# attribute: uniform

# module: random
# attribute: choice
random.choice(['Apply','Banana','Cherry','Dairymilk'])

# module: random
# attribute: sample
random.sample(['Apply','Banana','Cherry','Dairymilk'])

# module: math
# attribute: pi

# module: math
# attribute: sqrt

# module: math
# attribute: pi

# module: math
# attribute: e

# module: math
# attribute: sin

# %%
# module: random
# attribute: randint
 
import random

# %%
random.randint(1,10)
# Out:
# 9

# %%
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x00000292129892F0>>

# %%
# module: random
# attribute: random

import random

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(1,10)
# Out:
# 9

# %%
# module: random
# attribute: uniform
import random

# %%
random.uniform(1,10)
# Out:
# 6.129907217230091

# %%
help(random.uniform)
# Out:
# Help on method uniform in module random:
#
# uniform(a, b) method of random.Random instance
#     Get a random number in the range [a, b) or [a, b] depending on rounding.
#
#     The mean (expected value) and variance of the random variable are:
#
#         E[X] = (a + b) / 2
#         Var[X] = (b - a) ** 2 / 12

# %%
# module: random
# attribute: choice
random.choice(['Apply','Banana','Cherry','Dairymilk'])
# Out:
# 'Cherry'

# %%
random.choice(['Apply','Banana','Cherry','Dairymilk'])
# Out:
# 'Banana'

# %%
# module: random
# attribute: sample
random.sample(['Apply','Banana','Cherry','Dairymilk'])

# %%
# module: random
# attribute: sample
random.sample(['Apply','Banana','Cherry','Dairymilk'])

# %%
# module: random
# attribute: sample
random.sample(['Apply','Banana','Cherry','Dairymilk'])

# %%
help(random.sample)
# Out:
# Help on method sample in module random:
#
# sample(population, k, *, counts=None) method of random.Random instance
#     Chooses k unique random elements from a population sequence.
#
#     Returns a new list containing elements from the population while
#     leaving the original population unchanged.  The resulting list is
#     in selection order so that all sub-slices will also be valid random
#     samples.  This allows raffle winners (the sample) to be partitioned
#     into grand prize and second place winners (the subslices).
#
#     Members of the population need not be hashable or unique.  If the
#     population contains repeats, then each occurrence is a possible
#     selection in the sample.
#
#     Repeated elements can be specified one at a time or with the optional
#     counts parameter.  For example:
#
#         sample(['red', 'blue'], counts=[4, 2], k=5)
#
#     is equivalent to:
#
#         sample(['red', 'red', 'red', 'red', 'blue', 'blue'], k=5)
#
# ...

# %%
listt = ['Apply','Banana','Cherry','Dairymilk','mango']
random.sample(listt,k=2)
# Out:
# ['mango', 'Banana']

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e()
# Out:
# 2.718281828459045

# %%
import math

# %%
math.sin(0)        # 0.0
math.sin(math.pi/2)  # 1.0
math.sin(math.pi)    # 0.0
# Out:
# 1.2246467991473532e-16

# %%
inside bracket shift + tab
random.randin()

# %% [markdown]
# - module note found error
#      - it is installed we need to install
# - attribute not found in module
#      - we neednto check by apply: dir

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# import time
# attribute : sleep 

import time

# %%
print('hello')
# Out:
# hello

# %%
time.sleep(3)
print('hello')
# Out:
# hello

# %%
dir(time)
# Out:
# ['_STRUCT_TM_ITEMS',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'altzone',
#  'asctime',
#  'ctime',
#  'daylight',
#  'get_clock_info',
#  'gmtime',
#  'localtime',
#  'mktime',
#  'monotonic',
#  'monotonic_ns',
#  'perf_counter',
#  'perf_counter_ns',
#  'process_time',
#  'process_time_ns',
#  'sleep',
#  'strftime',
#  'strptime',
#  'struct_time',
#  'thread_time',
#  'thread_time_ns',
#  'time',
#  'time_ns',
#  'timezone',
#  'tzname']

# %%
time.time()
# Out:
# 1758293197.3944588

# %%
start = time.time()
time.sleep(5)
end=time.time()
print(f"the time taken is:{end-start}")
# Out:
# the time taken is:5.001115083694458

# %%
# module name: keyword
# attribute : rwlist

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
import random
random
# Out:
# <module 'random' from 'C:\\Users\\Rohit singh\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\random.py'>

# %%
pip freeze
# Out:
# anyio==4.9.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==3.0.0
# async-lru==2.0.5
# attrs==25.3.0
# babel==2.17.0
# beautifulsoup4==4.13.3
# bleach==6.2.0
# certifi==2025.1.31
# cffi==1.17.1
# charset-normalizer==3.4.1
# colorama==0.4.6
# comm==0.2.2
# contourpy==1.3.1
# cycler==0.12.1
# debugpy==1.8.13
# decorator==5.2.1
# defusedxml==0.7.1
# executing==2.2.0
# fastjsonschema==2.21.1
# fonttools==4.56.0
# fqdn==1.5.1
# h11==0.14.0
# httpcore==1.0.7
# httpx==0.28.1
# idna==3.10
# ipykernel==6.29.5
# ipython==9.0.2
# ipython_pygments_lexers==1.1.1
# ipywidgets==8.1.5
# isoduration==20.11.0
# jedi==0.19.2
# Jinja2==3.1.6
# json5==0.10.0
# jsonpointer==3.0.0
# jsonschema==4.23.0
# jsonschema-specifications==2024.10.1
# jupyter==1.1.1
# jupyter-console==6.6.3
# jupyter-events==0.12.0
# jupyter-lsp==2.2.5
# jupyter_client==8.6.3
# jupyter_core==5.7.2
# jupyter_server==2.15.0
# jupyter_server_terminals==0.5.3
# jupyterlab==4.3.6
# ...

# %% [markdown]
# **how to install**

# %% [raw]
# - all pip(Pip install package) commands we can do
#
#      - in jupyter notebook
#
#      - in anaconda promt (we called this as terminal)
#
# - Recommended appraoch is user **terminal**
#
# - while you are installing the package make sure **internet should be connect**
#
# - if you dont

# %%
import streamlit

# %%
import flask

# %%
import cv2

# %%
# pip install cv2
# pip install flask
# pip install streamlit

# %%
import cv2

# %%
pip install opencv-python
