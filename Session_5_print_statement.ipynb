# %%
num=100
num
# Out:
# 100

# %%
print(num)
# Out:
# 100

# %%
print(num=100) #wrong
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(num=100) #wrong
#
# TypeError: 'num' is an invalid keyword argument for print()

# %%
n1=10
n2=20
print(n1,n2)
# Out:
# 10 20

# %%
print(n1)
# Out:
# 10

# %%
print(n2)
# Out:
# 20

# %%
print(n1)
print(n2)
# Out:
# 10
# 20

# %%
print('hyderabad',100,10.5,True)
# Out:
# hyderabad 100 10.5 True

# %%
print(100 200) #wrong
# Out:
#   Cell In[12], line 1
#     print(100 200)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
n1=1000
n2=200
n3=n1+n2
print("the addition of 100 and 200 is 300.")
print("the addtion of n1 and n2 is n3.")
print("the addtion of",n1,"and",n2,"is",n3)
# Out:
# the addition of 100 and 200 is 300.
# the addtion of n1 and n2 is n3.
# the addtion of 1000 and 200 is 1200

# %%
name="python"
age=10
city="hyderabad"

# my name is python Im 10 year ols, came from hyderabad

print("my name is python Im 10 year old, came from hyderabad")
print("my name is",name, "Im",age, "year old came from",city)
# Out:
# my name is python Im 10 year old, came from hyderabad
# my name is python Im 10 year old came from hyderabad

# %%
n1=100
n2=200
n3=n1+n3
print("the addition of 100 and 200 is 300.")
print("the addition of {} and {} is {}.")
#"{},{},{}".format (10,20,30)
print("the addition of {} and {} is {}".format(n1,n2,n3))
# Out:
# the addition of 100 and 200 is 300.
# the addition of {} and {} is {}.
# the addition of 100 and 200 is 1300

# %%
name="rohit"
age=22
city="gwalior"

# my name is python Im 10 year ols, came from hyderabad

print("my name is python Im 10 year old, came from hyderabad")
print("my name is",name, "Im",age, "year old came from",city)
print("my name is {} Im {} year old came from {}".format(name,age,city))
# Out:
# my name is python Im 10 year old, came from hyderabad
# my name is rohit Im 22 year old came from gwalior
# my name is rohit Im 22 year old came from gwalior

# %% [markdown]
# **fstring metthod**

# %%
n1=100
n2=200
n3=n1+n2
print("the addition of 100 and 200 is 300.")
print("the addition of {} and {} is {}.")
print(f"the addition of {n1} and {n2} is {n3}")
# Out:
# the addition of 100 and 200 is 300.
# the addition of {} and {} is {}.
# the addition of 100 and 200 is 300

# %%
name="rohit"
age=22
city="gwalior"

# my name is python Im 10 year ols, came from hyderabad

print("my name is python Im 10 year old, came from hyderabad")
print("my name is",name, "Im",age, "year old came from",city)
print(f"my name is {name} Im {age} year old, came from {city}")
# Out:
# my name is python Im 10 year old, came from hyderabad
# my name is rohit Im 22 year old came from gwalior
# my name is rohit Im 22 year old, came from gwalior

# %%
#7x2=14
7*2
print("7x2=14")
print("7x2=",7*2)
print("7x2={}".format(7*2))
print(f"7x2={7*2}")
# Out:
# 7x2=14
# 7x2= 14
# 7x2=14
# 7x2=14

# %%
# wap take number n1,n2,n3 and find the value
# n1
# n2
# n3
# avg=<formua>
# the value of n1,n2, and n3 is avg

# %%
n1=10
n2=20
n3=30
sum=n1+n2+n3
avg=(n1+n2+n3)/3
print(f"the average of {n1}, {n2} and {n3} is:{avg}")
# Out:
# the average of 10, 20 and 30 is:20.0

# %%
n1 = 10
n2 = 20
n3 = 300

sum_val = n1 + n2 + n3
avg = sum_val / 3

print(f"The average of {n1}, {n2}, and {n3} is: {avg}")
# Out:
# The average of 10, 20, and 300 is: 110.0

# %%
# round(31.66)
# round (31.66,1)
# 31.<66>===<7>
#31.67

# %%
n1=25
n2=30
n3=40
avg=(n1+n2+n3)/3
avg1=round(avg,2)
avg1
# Out:
# 31.67

# %%
bill_amount=1000
tip_per=100
tip_amount=bill_amount*tip_per/100
total_bill=bill_amount+tip_per
print('the total amount bill is:',total_bill)
# Out:
# the total amount bill is: 1100

# %%
weight_in_kgs=60
onw_kgs_pounds=2.2
total_weight_in_pounds=60*2.2
print(
