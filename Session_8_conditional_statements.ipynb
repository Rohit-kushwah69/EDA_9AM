# %% [markdown]
# ## Conditional statements

# %%
- I want do something based on some condition

- I will go say hello if i know you

- I want to go to class if no rain

- if no rain then i will go to class  otherwise i will go to movie

    - if no rain then i will go to class else i will go to movie

- if i pass in firstclass i will study MBA in USA 
otherwise if i pass in second class i will study in good college india 
otherwise i will study in my town

    - if i pass in firstclass i will study MBA in USA 
     elif i pass in second class i will study in good college india 
     else i will study in my town


- if i pass in firstclass i will study MBA in USA 
otherwise if i pass in second class i will study in good college india 
otherwise if i pass in third class i will study in my town
othersie papa se belt treatment

# %% [markdown]
# **if**

# %%
if <condition>:
    <code>
    <code>

if=== condition ====: ==== indentation

# %%
10>0
# Out:
# True

# %%
10<0
# Out:
# False

# %%
10>=0
# Out:
# True

# %%
10<=0
# Out:
# False

# %%
10=10  # assign
# Out:
#   Cell In[11], line 1
#     10=10
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
10==10 # condition
# Out:
# True

# %%
10!=0
# Out:
# True

# %%
10!=10
# Out:
# False

# %%
if 10>0:           # if  True
    print('hello')
# Out:
# hello

# %%
if 10<0:           # if  False
    print('hello')

# %% [markdown]
# **mistake-1**

# %%
if 10>0:      
print('hello')
# Out:
#   Cell In[24], line 2
#     print('hello')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
if 10>0:
    print('hello')

# %% [markdown]
# **mistake-2**

# %%
if 10>0      
  print('hello')
# Out:
#   Cell In[27], line 1
#     if 10>0
#                  ^
# SyntaxError: expected ':'

# %% [markdown]
# **mistake-3**

# %%
if 10>0:      
    print('hello')
     print('hi')
# Out:
#   Cell In[30], line 3
#     print('hi')
#     ^
# IndentationError: unexpected indent

# %%
if 10>0:
    print('hello')
    print('hi')
# Out:
# hello
# hi

# %%
if 10>0:      
    print('hello')
    print('hi')
    print('im good')
# Out:
# hello
# hi
# im good

# %%
##########################
if 10>0:         #if   True
    print('hello')
    print('hi')
    print('im good')
####################################
print('wow')
# Out:
# hello
# hi
# im good
# wow

# %%
##########################
if 10>0:         #if   True
    print('hello')
    print('hi')
    print('im good')
####################################
 print('wow')
# Out:
#   File <string>:7
#     print('wow')
#                 ^
# IndentationError: unindent does not match any outer indentation level

# %%
print('hey')
##########################
if 10>0:
    print('hello')
    print('hi')
    print('im good')
####################################
print('wow')
# Out:
# hey
# hello
# hi
# im good
# wow

# %%
print('hey')  # hey
if 10>0:      # if  True
    print('hello')
    print('hi')
    if 20>10:  # if True
    print('im good')
print('wow')
# Out:
#   Cell In[48], line 6
#     print('im good')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 5

# %%
print('hey')  # hey
if 10>0:      # if  True
    print('hello')
    print('hi')
    if 20>10:  # if True
        print('im good')
print('wow')
# Out:
# hey
# hello
# hi
# im good
# wow

# %%
print('hey') 
if True:      
    print('hello')
    print('hi')
    if true:  # if True
        print('im good')
print('wow')
# Out:
# hey
# hello
# hi
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 5
#       3     print('hello')
#       4     print('hi')
# ----> 5     if true:  # if True
#       6         print('im good')
#       7 print('wow')
#
# NameError: name 'true' is not defined

# %%
print('hey') 
if True:      
    print('hello')
    print('hi')
    if True:  # if True
        print('im good')
print('wow')
# Out:
# hey
# hello
# hi
# im good
# wow

# %%
print('hey') 
if True:      
    print('hello')
    print('hi')
    if False: 
        print('im good')
print('wow')
# Out:
# hey
# hello
# hi
# wow

# %%
print('hey') 
if True:      
    print('hello')
    print('hi')
    if False: 
        print('im good')
    if True: 
        print('super')
print('wow')
# Out:
# hey
# hello
# hi
# super
# wow

# %%
print('hey') 
if True:      
    print('hello')
    print('hi')
    if False: 
        print('im good')
    if False: 
        print('super')
print('wow')
# Out:
# hey
# hello
# hi
# wow

# %%
print('company transfer')
if True:
    print('take over')
    print('company transfer')
    if True:
        print('take over')
        print('company transfer')
    if True:
        print('take over')
        print('company transfer')

print('happy family')
# Out:
# company transfer
# take over
# company transfer
# take over
# company transfer
# take over
# company transfer
# happy family

# %%
print('company transfer')
if True:
    print('take over')
    print('company transfer')
    if True:
        print('take over')
        print('company transfer')
    if False:
        print('take over')
        print('company transfer')

print('avg family')

# %%
print('company transfer')
if True:
    print('take over')
    print('company transfer')
    if False:
        print('take over')
        print('company transfer')
    if False:
        print('take over')
        print('company transfer')

print('sad family')

# %%
print('company transfer')
if True:
    print('take over')
    print('company transfer')
    if True:
        print('take over')
        print('company transfer')
        if True:
            print('take over')
            print('company transfer')

print('Happy')
# Out:
# company transfer
# take over
# company transfer
# take over
# company transfer
# take over
# company transfer
# Happy

# %%
print('company transfer')
if True:
    print('take over')
    print('company transfer')
    if True:
        print('take over')
        print('company transfer')
        if False:
            print('take over')
            print('company transfer')

print('avg')

# %%
print('company transfer')
if True:
    print('take over')
    print('company transfer')
    if False:
        print('take over')
        print('company transfer')
        if True:
            print('take over')
            print('company transfer')

print('avg')

# %%
print('company transfer')
if False:
    print('take over')
    print('company transfer')
    if True:
        print('take over')
        print('company transfer')
        if True:
            print('take over')
            print('company transfer')

print('old age home')
# Out:
# company transfer
# old age home

# %%
if True:
    a=10
    b=20
    c=a+b
    print(c)
# Out:
# 30

# %%
if True:
    pass

# %%
if True:
    break
# Out:
#   Cell In[80], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %% [markdown]
# **if-else**
#
# - if will be activated when condition True
#
# - else will be activated when condition False

# %%
if True:               #  if correct  ===> hello
    print('Hello')
else:
    print('Bye')
# Out:
# Hello

# %%
if False:               #  condition wron  ===> bye
    print('Hello')
else:
    print('Bye')
# Out:
# Bye

# %%
if 10>0:               #  if correct  ===> hello
    print('Hello')
else:
    print('Bye')
# Out:
# Hello

# %%
if 10<0:               #  condition wron  ===> bye
    print('Hello')
else:
    print('Bye')
# Out:
# Bye

# %%
print(1)
print(2)
#----------------------------------
if 10<0:               
    print('Hello')
else:
    print('Bye')
#-----------------------------------
print(3)
# Out:
# 1
# 2
# Bye
# 3

# %%
print(1)
print(2)
#----------------------------------
if 10>0:               
    print('Hello')
else:
    print('Bye')
#-----------------------------------
print(3)
# Out:
# 1
# 2
# Hello
# 3

# %%
print(1)
print(2)
#----------------------------------
if 10>0:               
    print('Hello')
    if True:
        print('good')
else:
    print('Bye')
#-----------------------------------
print(3)
# Out:
# 1
# 2
# Hello
# good
# 3

# %%
print(1)
print(2)
#----------------------------------
if 10>0:               
    print('Hello')
    if False:
        print('good')
    else:
        print('avg')
else:
    print('Bye')
#-----------------------------------
print(3)
# Out:
# 1
# 2
# Hello
# avg
# 3

# %%
print(1)
print(2)
#----------------------------------
if 10<0:               
    print('Hello')
    if False:
        print('good')
    else:
        print('avg')
else:
    print('Bye')
#-----------------------------------
print(3)
# Out:
# 1
# 2
# Bye
# 3

# %%
print(1)
print(2)
#----------------------------------
if 10<0:               
    print('Hello')
    if False:
        print('good')
    else:
        print('avg')
else:
    print('Bye')
    if 2==2:
        print('Okay')
#-----------------------------------
print(3)
# Out:
# 1
# 2
# Bye
# Okay
# 3

# %%
print(1)
print(2)
#----------------------------------
if 10>0:               
    print('Hello')
print('why are you in middile')
else:
    print('Bye')
#-----------------------------------
print(3)
# Out:
#   Cell In[23], line 7
#     else:
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Questions**

# %%
# WAP ask the user take a number and find it is even or odd
# idea
# num=eval()
# if <con>:
#    print('even')
# else:
#   print('odd')

# condition: any number gives reminder zero if we divide by 2

# %%
11/2
# Out:
# 5.5

# %%
11%2   # reminder
# Out:
# 1

# %%
11//2   # floor division
# Out:
# 5

# %%
num=eval(input('enter number:'))
if num%2==0:
    print(f'the {num} is an even')
else:
    print(f'the {num} is an odd')
# Out:
# enter number: 21
# the 21 is an odd

# %%
import random
num=random.randint(1,100)
if num%2==0:
    print(f'the {num} is an even')
else:
    print(f'the {num} is an odd')
# Out:
# the 27 is an odd

# %% [markdown]
# - always think like how can I provide value
#
#     - hard codes
#
#     - from keyboard
#
#     - random

# %%
num=100
if num%2==0:
    print(f'the {num} is an even')
else:
    print(f'the {num} is an odd')

num=eval(input('enter number:'))
if num%2==0:
    print(f'the {num} is an even')
else:
    print(f'the {num} is an odd')


import random
num=random.randint(1,100)
if num%2==0:
    print(f'the {num} is an even')
else:
    print(f'the {num} is an odd')

# %%
# Q3) wap ask ask the user enter a number
#     print postive if it is greater than zero
#     otherwise print negative
# idea:
# num=eval()
# if <con>:
#   print('postive')
# else:
#   print('negative')

# %%
num=eval(input('enter the number:'))
if num>0:
    print(f'{num} is +ve')
else:
    print(f'{num} is -ve')
# Out:
# enter the number: 0
# 0 is -ve

# %%
# Q4) 
#wap ask the user enter a number
#if it is greater than or equal to zero  10
#      if num>0
#         print(+)
#      else: 
#         print(zero)      
#otherwise print negative

# %%
num=eval(input('enter the number:'))
if num>=0:
    if num>0:
        print(f'{num} is +ve')
    else:
        print('It is a zero')
else:
    print(f'{num} is -ve')
# Out:
# enter the number: 0
# It is a zero

# %%
# Q5) casino play

# wap ask the user enter a number n1
# get a random number between 1 to 10 n2
# if n1 equal to n2 
#  print won
# other wise print katam

# %%
n1=random.randint(1,10)
print(n1)
n2=eval(input('enter a number between 1-10:'))
if n1==n2:
    print('you won')
else:
    print('you lost')
# Out:
# 4
# enter a number between 1-10: 4
# you won

# %%
original_pwd='omkar123'
user_pwd=input('enter your pwd')
if original_pwd==user_pwd:
    print('Successfully login')
else:
    print('try again')
# Out:
# enter your pwd Omkar123
# try again

# %%
# Q7)
# wap ask the user enter a course name
#     ask the user enter inst name
# if cname equal to data science and inst name Naresh it
#    print  life is secure
# otherwise 
#   print katam zindagi

# %%
cname=input('enter a course name:')
inst_name=input('enter a institute name:')
if cname=='data science' and inst_name=='NareshIT':
    print('you are safe')
else:
    print('katam')
# Out:
# enter a course name: data science
# enter a institute name: naresit
# katam

# %%
#lower string operation we will 

'Data science'.lower()=='data science'.lower()
# Out:
# True

# %%
'10'+'20'
# Out:
# '1020'

# %%
eval('10')+eval('20')
# Out:
# 30

# %%
eval(input())
# Out:
#  10
# 10

# %%
# Every one should go to lab   10.30 to 12.30
# all the assignments
# when dead line is done
# saturady exam error identify
# mcq  description

# %% [markdown]
# **if-elif-else**
#
# - whenever we have one condition two outputs then we choose if-else
#
#     - if need condition
#
#     - else does not need condition
#
# - when we have two conditions 3 outputs the we use if-elif-else
#
#     - if need condition
#
#     - elif need condition
#
#     - else does not need condition
#
# - if -elif -elif-else

# %%
# wap ask the user enter a nunber 
# if number equal to 1 print 'one'
# if number equal to 2 print 'two'
# if number equal to 3 print 'three'
# otherwise print enter valid number

# Wap ask the user take a nmber
# if number greater than zero print postive
# if number less than zero print negative
# if number equla to zero print zero
# otherwise print enter a valid number

# %%
num=eval(input('enter a number:'))
if num==1:
    print('one')
elif num==2:
    print('two')
elif num==3:
    print('three')
else:
    print('enter a valid number')
# Out:
# enter a number: 4
# enter a valid number

# %%
num=eval(input('enter a number:'))  # 5
if num>0:  # 5>0   True  entry ans
    print(f'{num} is a postive number')
elif num<0: # 5<0  False no entry stop
    print(f'{num} is a negative number')
elif num==0:
    print(f'{num} is a zero')
else:
    print('enter a valid number')
# Out:
# enter a number: 0
# 0 is a zero

# %%
num=eval(input('enter a number:'))
if num>0:  #  5>0  True
    print(f'{num} is a postive number')
if num<0: #  5<0  False
    print(f'{num} is a negative number')
elif num==0:
    print(f'{num} is a zero')
else:
    print('enter a valid number')
# Out:
# enter a number: 5
# 5 is a postive number
# enter a valid number

# %%
num=eval(input('enter a number:'))  #  20
if num>10:   #  20>10  Tr  entry  ans
    print(f'{num} is a greteater than 10')
elif num>5:  #  20>5  Tru  
    print(f'{num} greater than 5')
elif num>3:  # 20>3 
    print(f'{num} greater than 5')
else:
    print('enter a valid number')
# Out:
# enter a number: 20
# 20 is a greteater than 10

# %%
num=eval(input('enter a number:'))  #  20
if num>10:   #  20>10  Tr  entry  ans
    print(f'{num} is a greteater than 10')
if num>5:  #  20>5  Tru  
    print(f'{num} greater than 5')
if num>3:  # 20>3 
    print(f'{num} greater than 5')
else:
    print('enter a valid number')
# Out:
# enter a number: 20
# 20 is a greteater than 10
# 20 greater than 5
# 20 greater than 5

# %%
num = eval(input('Enter Number" ')) # 10
if num>8:  # if 10>0   positive
    print(f'{num} is Positive')
if num>5:  # if 10>5  correct
    print(f'{num} is negative')
if num==0:
    print(f'{num} is Zero')
else:
    print('Enter Valid Number')
# Out:
# Enter Number"  10
# 10 is Positive
# Enter Valid Number

# %%
# WAP ask the user enter perecentage of marks
# if marks gretaer than or equal to 75 print A grade
# if marks between 60 to 75 print B Grade
# if marks between 45 to 60 print C Grade
# if marks between 35 to 45 print D Grade
# otherwise fail

# %%
marks=eval(input("enter percentage of marks:"))  # 42
if marks>=75:  #  42>=75  F
    print("A garde")
elif marks>=60 and marks>=70:  # 42>=60  and 42>=70  F  60 70
    print("B grade")
elif marks<=40 and marks<=45:
    print("C grade")
elif marks<=30 and marks<=35:
    print("D garde")
else:
    print("Failed")

# %%
6>2  and  6<10
#T     and  T
# Out:
# True

# %%
2<6<10
# Out:
# True

# %%
marks=eval(input("enter percentage of marks:"))  # 42
if marks>=75:   #  90>=75   TR  
    print("A garde")
elif marks>=60:   # 90>=60  True
    print("B grade")
elif marks>=45:  # 90>=45  T
    print("C grade")
elif marks>=35:  # 90>=35  T
    print("D garde")
else:
    print("Failed")
# Out:
# enter percentage of marks: 90
# A garde

# %%
# WAP ask the user enterv age
# if age gretaer than 100 print unlucky person
# if age between 60 to 100 print SS
# if age between 30 to 60 print MA
# if age betwen 20 to 30 print Youth
# if age between 13 to 20 print teenag
# othersie print kid

# %%
age = eval(input("Please enter your age "))
if age>=100:
    print("Unlucky Person")
elif age >=60:
    print("SS")
elif age >=30:
    print("MA")
elif age >=20:
    print("Youth")
elif age>=13:
    print("Teenage")
else:
    print("Kid")
# Out:
# Please enter your age  18
# Teenage

# %%
# wap ask the user gender
# if gender equal to male
#     if age between 60 to 100 print Man
#     if age between 30 to 60 print MAM
#     if age betwen 20 to 30 print Young man
#     if age between 13 to 20 print boy
#     othersie print kid
# elif gender equal to female
#     if age between 60 to 100 print woman
#     if age between 30 to 60 print MAW
#     if age betwen 20 to 30 print Young G
#     if age between 13 to 20 print girl
#     othersie print kid
# otherwise:
#   enter a valid gender

# %%
gender = input('Enter your gender:').lower()
if gender == 'male':
    age = eval(input('Enter your age:'))
    if age>=60:
        print('Man')
    elif age>=30:
        print('Middle age man')
    elif age>=20:
        print('Young man')
    elif age>=13:
        print('boy')
    else:
        print('Kid')
elif gender == 'female':
    age = eval(input('Enter your age:'))
    if age>=60:
        print('Woman')
    elif age>=30:
        print('Middle age woman')
    elif age>=20:
        print('Young girl')
    elif age>=13:
        print('girl')
    else:
        print('Kid')
else:
    print('Enter a valid gender:')

Mohit Goswami 10:44
gender=input('Enter the gender')
age=eval(input('Enter the age'))
if gender=='male':
    if age>=60:
        print('Man')
    elif age>=30:
        print('Middle age man')
    elif age>=20:
        print('Young Man')
    else:
        print('Kid')
elif gender=='female':
    if age>=60:
        print('Women')
    elif age>=30:
        print('Middle age women')
    elif age>=20:
        print('Young Girl')
    else:
        print('Kid')
else:
    print('Enter a valid gender')

Bhargavi 10:45
age=int(input('enter your gender:'))
if gender==male:
    if age>=60 and age<100:
        print('Man')
    if age>=30 and age<60:
        print("MAM")
    if age>=20 and age<30:
        print("Young man")
    if age>=13 and age<20:
        print('boy')
    else:
        print('kid')
if  gender==female:
    if age>=60 and age<100:
        print('woman')
    if age>=30 and age<60:
        print("MAW")
    if age>=20 and age<30:
        print("Young G ")
    if age>=13 and age<20:
        print('girl')
    else:
        print('kid')
else:
    print('Enter a valid gender')

# %%
# wap ask the user enter number between 1 to 4
# if number equal to one
#    take two numbers and addition
# if number equal to two
#    take two numbers and subtraction
# if number equal to three
#    take two numbers and multiplication
# if number equal to four
#    take two numbers and divison
# else
#   enter a valid numbers
