# %%
a=100
b=200
c=a+b
c

# %% [markdown]
# - ## **Variable**
#     - sdfg
#         - dfg

# %% [markdown]
# # Variables

# %% [markdown]
# - Variable is use to store the value in a memory
#
# - the value canbe changed

# %%
num1 =100
# 100 strored ina variable num
num1
# Out:
# 100

# %%
num1=200
num1
# Out:
# 200

# %%
omkar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 omkar
#
# NameError: name 'omkar' is not defined

# %%
n1=100
n2=200
n3=300
n=n1+n2+n5   # line:4 5 name 'n5' is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 n2=200
#       3 n3=300
# ----> 4 n=n1+n2+n4   # 4 name 'n4' is not defined
#
# NameError: name 'n4' is not defined

# %%
n1=100
n2=200
n3=300
n=n1+n2+n4   # Line:4 name 'n4' is not defined
n5=400
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 n2=200
#       3 n3=300
# ----> 4 n=n1+n2+n4   # Line:4 name 'n4' is not defined
#       5 n5=400
#
# NameError: name 'n4' is not defined

# %%
n1=100 #ans1
n2=200  #ans2
n5=500
n=n1+n2+n5   # 5 name 'n4' is not defined
n
# Out:
# 800

# %%
n1=100
n2=200

# %%
n1=100,200
n1 #tuple bracket
# Out:
# (100, 200)

# %%
n1,n2=100,200
print(n1)
print(n2)
# Out:
# 100
# 200

# %%
n1,n2 =200
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 n1,n2 =200
#
# TypeError: cannot unpack non-iterable int object

# %%
NUMBER=100

# %%
NUMBER
# Out:
# 100

# %%
number one =100
# Out:
#   Cell In[19], line 1
#     number one =100
#            ^
# SyntaxError: invalid syntax

# %%
Overalljustification=200

# %%
Overalljustification
# Out:
# 200

# %% [markdown]
# - Variables are case sensitive
#
# - Variables canne uper case also canne lower case
#
# - Variables should not start with number
#
# - Variables does not include special characters
#
# - Variales can contain underscores
#
# - Variables can not be a math inbuilt function
#
# - Variables can not a be reserved words or keywords
